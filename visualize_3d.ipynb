# %% [markdown]
# <a href="https://colab.research.google.com/github/twyeh/solid-state-physics/blob/main/visualize_3d.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# (visualize-3d-nb)=
# # Visualizing 3D tight-binding models
#
# This example demonstrates how to visualize a 3D tight-binding model using the `TBModel.visualize_3d` function.
#
# :::{note}
#
# This feature requires the `plotly` library to be installed.
#
# You can install it via pip:
#
# ```bash
# pip install plotly
# ```
# or via conda:
#
# ```bash
# conda install plotly
# ```
# :::

# %%
# !pip install pythtb plotly
# Out:
# Collecting pythtb
#   Downloading pythtb-2.0.0-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (5.24.1)
# Requirement already satisfied: numpy>=2.0 in /usr/local/lib/python3.12/dist-packages (from pythtb) (2.0.2)
# Requirement already satisfied: matplotlib>=3.9 in /usr/local/lib/python3.12/dist-packages (from pythtb) (3.10.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->pythtb) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->pythtb) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->pythtb) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->pythtb) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->pythtb) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->pythtb) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->pythtb) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.9->pythtb) (1.17.0)
# Downloading pythtb-2.0.0-py3-none-any.whl (196 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.3/196.3 kB 6.8 MB/s eta 0:00:00
# Installing collected packages: pythtb
# Successfully installed pythtb-2.0.0

# %%
from pythtb.models import fu_kane_mele

# Reference Model
t = 1  # spin-independent first-neighbor hop
soc = 1  # spin-dependent second-neighbor hop
dt = [2, 0, 0, 0]  # hopping modulation along (111) direction
fkm_model = fu_kane_mele(t, soc, dt=dt)

fig = fkm_model.visualize_3d(draw_hoppings=True)
fig
# Out:
# <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="00a926b9-b731-4831-841d-a904000910ec" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("00a926b9-b731-4831-841d-a904000910ec")) {                    Plotly.newPlot(                        "00a926b9-b731-4831-841d-a904000910ec",                        [{"hoverinfo":"none","line":{"color":"blue","width":4},"mode":"lines","showlegend":false,"x":[0.0,0.0],"y":[0.0,1.0],"z":[0.0,1.0],"type":"scatter3d"},{"anchor":"tip","colorscale":[[0,"blue"],[1,"blue"]],"name":"a0","showscale":false,"sizemode":"absolute","sizeref":0.2,"u":[0.0],"v":[0.7071067811865475],"w":[0.7071067811865475],"x":[0.0],"y":[1.0],"z":[1.0],"type":"cone"},{"hoverinfo":"none","mode":"text","showlegend":false,"text":["a0"],"textfont":{"color":"blue","size":12},"textposition":"top center","x":[0.0],"y":[1.0],"z":[1.0],"type":"scatter3d"},{"hoverinfo":"none","line":{"color":"blue","width":4},"mode":"lines","showlegend":false,"x":[0.0,1.0],"y":[0.0,0.0],"z":[0.0,1.0],"type":"scatter3d"},{"anchor":"tip","colorscale":[[0,"blue"],[1,"blue"]],"name":"a1","showscale":false,"sizemode":"absolute","sizeref":0.2,"u":[0.7071067811865475],"v":[0.0],"w":[0.7071067811865475],"x":[1.0],"y":[0.0],"z":[1.0],"type":"cone"},{"hoverinfo":"none","mode":"text","showlegend":false,"text":["a1"],"textfont":{"color":"blue","size":12},"textposition":"top center","x":[1.0],"y":[0.0],"z":[1.0],"type":"scatter3d"},{"hoverinfo":"none","line":{"color":"blue","width":4},"mode":"lines","showlegend":false,"x":[0.0,1.0],"y":[0.0,1.0],"z":[0.0,0.0],"type":"scatter3d"},{"anchor":"tip","colorscale":[[0,"blue"],[1,"blue"]],"name":"a2","showscale":false,"sizemode":"absolute","sizeref":0.2,"u":[0.7071067811865475],"v":[0.7071067811865475],"w":[0.0],"x":[1.0],"y":[1.0],"z":[0.0],"type":"cone"},{"hoverinfo":"none","mode":"text","showlegend":false,"text":["a2"],"textfont":{"color":"blue","size":12},"textposition":"top center","x":[1.0],"y":[1.0],"z":[0.0],"type":"scatter3d"},{"hoverinfo":"text","marker":{"color":"#440154","size":10},"mode":"markers","name":"Orbital 0","text":["Orbital 0, Onsite Energy = 0"],"x":[0.0],"y":[0.0],"z":[0.0],"type":"scatter3d"},{"hoverinfo":"text","marker":{"color":"#fde725","size":10},"mode":"markers","name":"Orbital 1","text":["Orbital 1, Onsite Energy = 0"],"x":[0.5],"y":[0.5],"z":[0.5],"type":"scatter3d"},{"hoverinfo":"text","marker":{"color":"#440154","size":8},"mode":"markers","name":"","showlegend":false,"text":["Orbital 0, \n Onsite Energy: 0"],"x":[0.0],"y":[0.0],"z":[0.0],"type":"scatter3d"},{"hoverinfo":"text","marker":{"color":"#fde725","size":8},"mode":"markers","name":"","showlegend":false,"text":["Orbital 1, onsite energy: 0"],"x":[0.5],"y":[-0.5],"z":[-0.5],"type":"scatter3d"},{"hoverinfo":"text","marker":{"color":"#440154","size":8},"mode":"markers","name":"","showlegend":false,"text":["Orbital 0, \n Onsite Energy: 0"],"x":[0.0],"y":[1.0],"z":[1.0],"type":"scatter3d"},{"hoverinfo":"text","marker":{"color":"#fde725","size":8},"mode":"markers","name":"","showlegend":false,"text":["Orbital 1, onsite energy: 0"],"x":[0.5],"y":[0.5],"z":[0.5],"type":"scatter3d"},{"hoverinfo":"text","marker":{"color":"#440154","size":8},"mode":"markers","name":"","showlegend":false,"text":["Orbital 0, \n Onsite Energy: 0"],"x":[0.0],"y":[0.0],"z":[0.0],"type":"scatter3d"},{"hoverinfo":"text","marker":{"color":"#fde725","size":8},"mode":"markers","name":"","showlegend":false,"text":["Orbital 1, onsite energy: 0"],"x":[-0.5],"y":[0.5],"z":[-0.5],"type":"scatter3d"},{"hoverinfo":"text","marker":{"color":"#440154","size":8},"mode":"markers","name":"","showlegend":false,"text":["Orbital 0, \n Onsite Energy: 0"],"x":[1.0],"y":[0.0],"z":[1.0],"type":"scatter3d"},{"hoverinfo":"text","marker": ...
